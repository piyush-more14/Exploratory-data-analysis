# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\PIYUSH\DA\EDA\all_csv sorted.csv")

# %%
df
# Out:
#      S.NO Country code                           Country  Continental region  \
# 0       0           IL                            Israel           NEAR EAST
# 1       1           KG                        Kyrgyzstan   CIS (FORMER USSR)
# 2       2           FJ                              Fiji             OCEANIA
# 3       3           IT                             Italy      WESTERN EUROPE
# 4       4           SD                             Sudan  SUB-SAHARAN AFRICA
# ..    ...          ...                               ...                 ...
# 237   239           VA           Vatican City (Holy See)              Europe
# 238   240           VE                         Venezuela       SOUTH AMERICA
# 239   241           WF                 Wallis and Futuna             OCEANIA
# 240   242           CD  Democratic Republic of the Congo  SUB-SAHARAN AFRICA
# 241   243           ZW                          Zimbabwe  SUB-SAHARAN AFRICA
#
# ...

# %%
df.isnull().sum()
# Out:
# S.NO                                0
# Country code                        0
# Country                             0
# Continental region                  0
# NO. OF Internet Plans              11
# Average price of 1GB (USD)          0
# Cheapest 1GB for 30 days (USD)     11
# Most expensive 1GB (USD)           11
# Average price of 1GB_2021          11
# Average price of 1GB_2020          11
# Internet users                     30
# Population                         32
# Avg \n(Mbit/s)Ookla               101
# dtype: int64

# %%
df.drop(['Country code','Continental region','NO. OF Internet Plans','S.NO'], axis=1,inplace=True)

# %%
df
# Out:
#                               Country  \
# 0                              Israel
# 1                          Kyrgyzstan
# 2                                Fiji
# 3                               Italy
# 4                               Sudan
# ..                                ...
# 237           Vatican City (Holy See)
# 238                         Venezuela
# 239                 Wallis and Futuna
# 240  Democratic Republic of the Congo
# 241                          Zimbabwe
#
#                    Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# 0                                        0.05                            0.02
# 1                                        0.15                            0.10
# 2                                        0.19                            0.05
# 3                                        0.27                            0.09
# 4                                        0.27                            0.03
# ...

# %%
df.isnull().sum()
# Out:
# Country                             0
# Average price of 1GB (USD)          0
# Cheapest 1GB for 30 days (USD)     11
# Most expensive 1GB (USD)           11
# Average price of 1GB_2021          11
# Average price of 1GB_2020          11
# Internet users                     30
# Population                         32
# Avg \n(Mbit/s)Ookla               101
# dtype: int64

# %%
sns.heatmap(df.isnull(), yticklabels=False, cmap='viridis')
# Out:
# <Axes: >

# %%
#df['Avg \n(Mbit/s)Ookla'].fillna(df['Avg \n(Mbit/s)Ookla'].mean(),inplace=True)

# %%
df
# Out:
#                               Country  \
# 0                              Israel
# 1                          Kyrgyzstan
# 2                                Fiji
# 3                               Italy
# 4                               Sudan
# ..                                ...
# 237           Vatican City (Holy See)
# 238                         Venezuela
# 239                 Wallis and Futuna
# 240  Democratic Republic of the Congo
# 241                          Zimbabwe
#
#                    Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# 0                                        0.05                            0.02
# 1                                        0.15                            0.10
# 2                                        0.19                            0.05
# 3                                        0.27                            0.09
# 4                                        0.27                            0.03
# ...

# %%
df.shape
# Out:
# (242, 9)

# %%
df.iloc[237]['Country']
# Out:
# 'Vatican City (Holy See)'

# %%
for index,row in df.iterrows():
    if np.isnan(pd.to_numeric(row['Average price of 1GB (USD)'],errors='coerce')):
        df.drop(index,inplace=True)

# %%
df['Average price of 1GB (USD)'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 231 entries, 0 to 230
# Series name: Average price of 1GB (USD)
# Non-Null Count  Dtype
# --------------  -----
# 231 non-null    object
# dtypes: object(1)
# memory usage: 3.6+ KB

# %%
sns.heatmap(df.isnull(),cmap='viridis')
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# Country                            0
# Average price of 1GB (USD)         0
# Cheapest 1GB for 30 days (USD)     0
# Most expensive 1GB (USD)           0
# Average price of 1GB_2021          0
# Average price of 1GB_2020          0
# Internet users                    26
# Population                        28
# Avg \n(Mbit/s)Ookla               93
# dtype: int64

# %%
df.shape
# Out:
# (231, 9)

# %%
df['Avg \n(Mbit/s)Ookla']=df['Avg \n(Mbit/s)Ookla'].fillna(df['Avg \n(Mbit/s)Ookla'].mean())

# %%
df.tail()
# Out:
#                                           Country Average price of 1GB (USD)  \
# 226                                        Malawi                      25.46
# 227                         São Tomé and Príncipe                      30.97
# 228  Saint Helena, Ascension and Tristan da Cunha                      39.87
# 229                              Falkland Islands                      44.56
# 230                             Equatorial Guinea                      49.67
#
#      Cheapest 1GB for 30 days (USD)  Most expensive 1GB (USD)  \
# 226                           20.37                     25.46
# 227                           13.27                    121.65
# 228                           38.57                     51.42
# 229                           29.71                     82.26
# 230                           45.16                     63.22
#
#     Average price of 1GB_2021 Average price of 1GB_2020 Internet users  \
# ...

# %%
df.isna().sum()
# Out:
# Country                            0
# Average price of 1GB (USD)         0
# Cheapest 1GB for 30 days (USD)     0
# Most expensive 1GB (USD)           0
# Average price of 1GB_2021          0
# Average price of 1GB_2020          0
# Internet users                    26
# Population                        28
# Avg \n(Mbit/s)Ookla                0
# dtype: int64

# %%
sns.heatmap(df.isna(),cmap='viridis')
# Out:
# <Axes: >

# %%
df['Internet users'].info()
df['Population'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 231 entries, 0 to 230
# Series name: Internet users
# Non-Null Count  Dtype
# --------------  -----
# 205 non-null    object
# dtypes: object(1)
# memory usage: 3.6+ KB
# <class 'pandas.core.series.Series'>
# Int64Index: 231 entries, 0 to 230
# Series name: Population
# Non-Null Count  Dtype
# --------------  -----
# 203 non-null    object
# dtypes: object(1)
# memory usage: 3.6+ KB

# %%
df['Internet users']=df['Internet users'].str.replace(',','')
df['Internet users']=pd.to_numeric(df['Internet users'])

# %%
df.head(1)
# Out:
#   Country Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# 0  Israel                       0.05                            0.02
#
#    Most expensive 1GB (USD) Average price of 1GB_2021  \
# 0                     20.95                      0.11
#
#   Average price of 1GB_2020  Internet users Population  Avg \n(Mbit/s)Ookla
# 0                       0.9       6788737.0  83,81,516                28.01

# %%
df['Population']=df['Population'].str.replace(',','')
df['Population']=pd.to_numeric(df['Population'])

# %%
df.head(1)
# Out:
#   Country Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# 0  Israel                       0.05                            0.02
#
#    Most expensive 1GB (USD) Average price of 1GB_2021  \
# 0                     20.95                      0.11
#
#   Average price of 1GB_2020  Internet users  Population  Avg \n(Mbit/s)Ookla
# 0                       0.9       6788737.0   8381516.0                28.01

# %%
df['Internet users'].info()
df['Population'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 231 entries, 0 to 230
# Series name: Internet users
# Non-Null Count  Dtype
# --------------  -----
# 205 non-null    float64
# dtypes: float64(1)
# memory usage: 3.6 KB
# <class 'pandas.core.series.Series'>
# Int64Index: 231 entries, 0 to 230
# Series name: Population
# Non-Null Count  Dtype
# --------------  -----
# 203 non-null    float64
# dtypes: float64(1)
# memory usage: 3.6 KB

# %%
df.isna().sum()
# Out:
# Country                            0
# Average price of 1GB (USD)         0
# Cheapest 1GB for 30 days (USD)     0
# Most expensive 1GB (USD)           0
# Average price of 1GB_2021          0
# Average price of 1GB_2020          0
# Internet users                    26
# Population                        28
# Avg \n(Mbit/s)Ookla                0
# dtype: int64

# %%
df['Internet users']=df['Internet users'].fillna(df['Internet users'].mean())
df['Population']=df['Population'].fillna(df['Population'].mean())

# %%
df.isna().sum()
# Out:
# Country                           0
# Average price of 1GB (USD)        0
# Cheapest 1GB for 30 days (USD)    0
# Most expensive 1GB (USD)          0
# Average price of 1GB_2021         0
# Average price of 1GB_2020         0
# Internet users                    0
# Population                        0
# Avg \n(Mbit/s)Ookla               0
# dtype: int64

# %%
df
# Out:
#                                           Country Average price of 1GB (USD)  \
# 0                                          Israel                       0.05
# 1                                      Kyrgyzstan                       0.15
# 2                                            Fiji                       0.19
# 3                                           Italy                       0.27
# 4                                           Sudan                       0.27
# ..                                            ...                        ...
# 226                                        Malawi                      25.46
# 227                         São Tomé and Príncipe                      30.97
# 228  Saint Helena, Ascension and Tristan da Cunha                      39.87
# 229                              Falkland Islands                      44.56
# 230                             Equatorial Guinea                      49.67
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 231 entries, 0 to 230
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country                         231 non-null    object
#  1   Average price of 1GB (USD)      231 non-null    object
#  2   Cheapest 1GB for 30 days (USD)  231 non-null    float64
#  3   Most expensive 1GB (USD)        231 non-null    float64
#  4   Average price of 1GB_2021       231 non-null    object
#  5   Average price of 1GB_2020       231 non-null    object
#  6   Internet users                  231 non-null    float64
#  7   Population                      231 non-null    float64
#  8   Avg
# (Mbit/s)Ookla              231 non-null    float64
# dtypes: float64(5), object(4)
# memory usage: 18.0+ KB

# %%
df['Average price of 1GB_2021']=pd.to_numeric(df['Average price of 1GB_2021'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 231 entries, 0 to 230
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country                         231 non-null    object
#  1   Average price of 1GB (USD)      231 non-null    object
#  2   Cheapest 1GB for 30 days (USD)  231 non-null    float64
#  3   Most expensive 1GB (USD)        231 non-null    float64
#  4   Average price of 1GB_2021       229 non-null    float64
#  5   Average price of 1GB_2020       231 non-null    object
#  6   Internet users                  231 non-null    float64
#  7   Population                      231 non-null    float64
#  8   Avg
# (Mbit/s)Ookla              231 non-null    float64
# dtypes: float64(6), object(3)
# memory usage: 18.0+ KB

# %%
df['Average price of 1GB (USD)']=pd.to_numeric(df['Average price of 1GB (USD)'],errors='coerce')
df['Average price of 1GB_2020']=pd.to_numeric(df['Average price of 1GB_2020'],errors='coerce')

# %%
df.head()
# Out:
#       Country  Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# 0      Israel                        0.05                            0.02
# 1  Kyrgyzstan                        0.15                            0.10
# 2        Fiji                        0.19                            0.05
# 3       Italy                        0.27                            0.09
# 4       Sudan                        0.27                            0.03
#
#    Most expensive 1GB (USD)  Average price of 1GB_2021  \
# 0                     20.95                       0.11
# 1                      7.08                       0.21
# 2                      0.85                       0.59
# 3                      3.54                       0.43
# 4                      0.92                       0.63
#
#    Average price of 1GB_2020  Internet users  Population  Avg \n(Mbit/s)Ookla
# 0                       0.90       6788737.0   8381516.0                28.01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 231 entries, 0 to 230
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country                         231 non-null    object
#  1   Average price of 1GB (USD)      231 non-null    float64
#  2   Cheapest 1GB for 30 days (USD)  231 non-null    float64
#  3   Most expensive 1GB (USD)        231 non-null    float64
#  4   Average price of 1GB_2021       229 non-null    float64
#  5   Average price of 1GB_2020       228 non-null    float64
#  6   Internet users                  231 non-null    float64
#  7   Population                      231 non-null    float64
#  8   Avg
# (Mbit/s)Ookla              231 non-null    float64
# dtypes: float64(8), object(1)
# memory usage: 18.0+ KB

# %%
df.isna().sum()
# Out:
# Country                           0
# Average price of 1GB (USD)        0
# Cheapest 1GB for 30 days (USD)    0
# Most expensive 1GB (USD)          0
# Average price of 1GB_2021         2
# Average price of 1GB_2020         3
# Internet users                    0
# Population                        0
# Avg \n(Mbit/s)Ookla               0
# dtype: int64

# %%
df['Average price of 1GB_2021'] = df['Average price of 1GB_2021'].fillna(df['Average price of 1GB_2021'].mean())
df['Average price of 1GB_2020']=df['Average price of 1GB_2020'].fillna(df['Average price of 1GB_2020'].mean())

# %%
df.isnull().sum()
# Out:
# Country                           0
# Average price of 1GB (USD)        0
# Cheapest 1GB for 30 days (USD)    0
# Most expensive 1GB (USD)          0
# Average price of 1GB_2021         0
# Average price of 1GB_2020         0
# Internet users                    0
# Population                        0
# Avg \n(Mbit/s)Ookla               0
# dtype: int64

# %%
df.shape
# Out:
# (231, 9)

# %%
df.head()
# Out:
#       Country  Average price of 1GB (USD)  Cheapest 1GB for 30 days (USD)  \
# 0      Israel                        0.05                            0.02
# 1  Kyrgyzstan                        0.15                            0.10
# 2        Fiji                        0.19                            0.05
# 3       Italy                        0.27                            0.09
# 4       Sudan                        0.27                            0.03
#
#    Most expensive 1GB (USD)  Average price of 1GB_2021  \
# 0                     20.95                       0.11
# 1                      7.08                       0.21
# 2                      0.85                       0.59
# 3                      3.54                       0.43
# 4                      0.92                       0.63
#
#    Average price of 1GB_2020  Internet users  Population  Avg \n(Mbit/s)Ookla
# 0                       0.90       6788737.0   8381516.0                28.01
# ...

# %% [markdown]
# ### TOP 5 Internet Users

# %%
top_users = df.sort_values(by='Internet users', ascending=True)

# %%
plt.pie(top_users['Internet users'].tail(5), labels=top_users['Country'].tail(5),autopct='%.2f%%')
plt.title('Countries with most Internet users')
plt.show()

# %% [markdown]
# ## Bottom 5 Internet Users

# %%
bottom_5=top_users.head(5)

# %%
bottom_5
# Out:
#                                           Country  Average price of 1GB (USD)  \
# 202                                          Niue                        7.37
# 169                                    Montserrat                        4.01
# 229                              Falkland Islands                       44.56
# 228  Saint Helena, Ascension and Tristan da Cunha                       39.87
# 196                                        Tuvalu                        6.35
#
#      Cheapest 1GB for 30 days (USD)  Most expensive 1GB (USD)  \
# 202                            4.48                     28.69
# 169                            1.11                     29.23
# 229                           29.71                     82.26
# 228                           38.57                     51.42
# 196                            5.72                     10.17
#
#      Average price of 1GB_2021  Average price of 1GB_2020  Internet users  \
# ...

# %%
plt.pie(bottom_5['Internet users'], labels=bottom_5['Country'], autopct='%.2f%%')
plt.show()

# %%
sns.lineplot(x=top_users['Internet users'], y=top_users['Average price of 1GB (USD)'])
plt.show()

# %%
top_users
# Out:
#                                           Country  Average price of 1GB (USD)  \
# 202                                          Niue                        7.37
# 169                                    Montserrat                        4.01
# 229                              Falkland Islands                       44.56
# 228  Saint Helena, Ascension and Tristan da Cunha                       39.87
# 196                                        Tuvalu                        6.35
# ..                                            ...                         ...
# 48                                         Brazil                        0.92
# 11                                      Indonesia                        0.42
# 153                                 United States                        3.33
# 27                                          India                        0.68
# 16                                          China                        0.52
#
# ...

# %% [markdown]
# ## Data Literacy in countries

# %%
sample=df.sample(frac=0.2)

# %%
plt.figure(figsize=(9, 5))
sns.barplot(x=sample['Country'],y=(sample['Internet users']/sample['Population'])*100,data=df)
plt.xticks(rotation=90)
plt.ylabel('% age users')
plt.title('Data Literacy')
plt.show()

# %% [markdown]
# ## Price difference between 2020 and 2021

# %%
plt.bar(y=top_users['Country'].tail(), x=top_users['Average price of 1GB_2020'].tail())
plt.bar(y=top_users['Country'].tail(), x=top_users['Average price of 1GB_2021'].tail())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 plt.bar(y=top_users['Country'].tail(), x=top_users['Average price of 1GB_2020'].tail())
#       2 plt.bar(y=top_users['Country'].tail(), x=top_users['Average price of 1GB_2021'].tail())
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
sample = sample.sort_values(by=)
# Out:
#                               Country  Average price of 1GB (USD)  \
# 219                    Cayman Islands                       11.97
# 53                        Afghanistan                        1.02
# 173               Antigua and Barbuda                        4.44
# 206              United Arab Emirates                        7.62
# 73                        El Salvador                        1.33
# 216          Virgin Islands (British)                        9.54
# 60                           Djibouti                        1.12
# 150                          Maldives                        3.24
# 149                           Comoros                        3.21
# 75                            Estonia                        1.39
# 224                      Turkmenistan                       21.41
# 124                         Argentina                        2.38
# 77                     United Kingdom                        1.42
# ...

# %%
sns.lineplot()

# %%
sns.stripplot(x=sample1['Average price of 1GB (USD at the start of 2021)'],y=sample1['Average price of 1GB (USD – at start of 2020)'],data=sample1)

# %% [markdown]
# ## Prices of top and bottom 5 Countries

# %%
prices = df.sort_values(by='Most expensive 1GB (USD)', ascending=True)

# %%
prices
# Out:
#                  Country  Average price of 1GB (USD)  \
# 13            San Marino                        0.43
# 2                   Fiji                        0.19
# 4                  Sudan                        0.27
# 40                Bhutan                        0.83
# 16                 China                        0.52
# ..                   ...                         ...
# 100  Trinidad and Tobago                        1.90
# 133        Faroe Islands                        2.64
# 152                 Mali                        3.28
# 198        New Caledonia                        6.49
# 212               Greece                        8.16
#
#      Cheapest 1GB for 30 days (USD)  Most expensive 1GB (USD)  \
# 13                             0.24                      0.63
# 2                              0.05                      0.85
# 4                              0.03                      0.92
# 40                             0.33                      1.06
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=prices['Country'].head(5),y=prices['Most expensive 1GB (USD)'].head(5))
plt.title('Least Expensive Internet')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=prices['Country'].tail(5),y=prices['Most expensive 1GB (USD)'].tail(5))
plt.title('Most Expensive Internet')
plt.show()

# %% [markdown]
# ## Highest Speed Internet

# %%
speed = df.sort_values(by='Avg \n(Mbit/s)Ookla', ascending=False)

# %%
speed
# Out:
#                   Country  Average price of 1GB (USD)  \
# 206  United Arab Emirates                        7.62
# 192                Norway                        5.81
# 148                 Qatar                        3.20
# 180           South Korea                        4.72
# 174   Aruba (Netherlands)                        4.44
# ..                    ...                         ...
# 26                  Ghana                        0.66
# 21                Somalia                        0.60
# 131            Tajikistan                        2.60
# 53            Afghanistan                        1.02
# 92              Palestine                        1.71
#
#      Cheapest 1GB for 30 days (USD)  Most expensive 1GB (USD)  \
# 206                            0.80                     34.30
# 192                            1.74                     29.03
# 148                            1.10                      4.39
# 180                            0.06                     96.88
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=speed['Country'].head(5),y=speed['Avg \n(Mbit/s)Ookla'].head(5))
plt.title('Highest Internet Speed')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=speed['Country'].tail(5),y=speed['Avg \n(Mbit/s)Ookla'].tail(5))
plt.title('Lowest Internet Speed')
plt.show()

# %%
df
# Out:
#                                           Country  Average price of 1GB (USD)  \
# 0                                          Israel                        0.05
# 1                                      Kyrgyzstan                        0.15
# 2                                            Fiji                        0.19
# 3                                           Italy                        0.27
# 4                                           Sudan                        0.27
# ..                                            ...                         ...
# 226                                        Malawi                       25.46
# 227                         São Tomé and Príncipe                       30.97
# 228  Saint Helena, Ascension and Tristan da Cunha                       39.87
# 229                              Falkland Islands                       44.56
# 230                             Equatorial Guinea                       49.67
#
# ...

# %%
top_users.head()
# Out:
#                                           Country  Average price of 1GB (USD)  \
# 202                                          Niue                        7.37
# 169                                    Montserrat                        4.01
# 229                              Falkland Islands                       44.56
# 228  Saint Helena, Ascension and Tristan da Cunha                       39.87
# 196                                        Tuvalu                        6.35
#
#      Cheapest 1GB for 30 days (USD)  Most expensive 1GB (USD)  \
# 202                            4.48                     28.69
# 169                            1.11                     29.23
# 229                           29.71                     82.26
# 228                           38.57                     51.42
# 196                            5.72                     10.17
#
#      Average price of 1GB_2021  Average price of 1GB_2020  Internet users  \
# ...

# %%
sns.distplot(top_users['Avg \n(Mbit/s)Ookla'])
plt.show()
